# %% [markdown]
# Standard Library overview

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
# random module
import random

print(random.randint(1, 10))  # prints a random integer between 1 and 10
print(random.choice(['apple', 'banana', 'cherry','orange']))  # prints a random choice from the list

# %%
### File and directory management
import os
print(os.getcwd())  # prints the current working directory
print(os.listdir())  # prints the list of files and directories in the current working directory

os.mkdir('test_dir')
# Out:
# /home/ufc/Projects/Data_Science/Python-Bootcamp/modules
# ['5.1-import.ipynb', 'packages', '5.2-standardlibrary.ipynb']

# %%
## Data Serialization

import json

data = {'name': 'Rakesh', 'age':25}

json_str = json.dumps(data)

print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)

print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Rakesh", "age": 25}
# <class 'str'>
# {'name': 'Rakesh', 'age': 25}
# <class 'dict'>

# %%
### CSV

import csv

with  open('example.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name', 'age'])
    writer.writerow(['Rakesh U', 25])

with open('example.csv', mode='r') as file:
    reader = csv.reader(file)

    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Rakesh U', '25']

# %%
### date
from datetime import datetime, timedelta

now = datetime.now()

print(now)

yesterday = now - timedelta(days=1)

print(yesterday)
# Out:
# 2026-09-20 12:43:02.956997
# 2026-09-19 12:43:02.956997

# %%
## time

import time
print(time.time())

time.sleep(2)
print(time.time())
# Out:
# 1789888506.7836785
# 1789888508.7841573
