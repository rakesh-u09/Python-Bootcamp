# %%
import math
print(math.pi)

# %%
print(math.sqrt(16))
# Out:
# 4.0

# %%
from math import sqrt, pi

print(sqrt(25))
print(pi)
print(sqrt(36))

# %%
from packages.maths import addition
print(addition(5, 10))
# Out:
# 15

# %%
from packages import maths
print(maths.addition(20, 30))
# Out:
# 50

# %%
from packages.subpackages.mult import multiplication
print(multiplication(5, 10))
# Out:
# 50
